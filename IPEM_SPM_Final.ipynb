# %%
import spm1d
import pandas as pd
import numpy as np
import glob, random, os
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
################ Patient information ###########################
patientData = pd.read_excel("Data\\Test.xlsx",usecols='BF:GO')

def analysingExcelData(data):

    patientData1 = np.array(data)

    leftPelvicP = []
    leftHipP = []
    leftKneeP = []
    leftAnkleP = []
    leftFootPitchP = []
    leftFootProgressionP = []
    rightPelvicP = []
    rightHipP = []
    rightKneeP = []
    rightAnkleP = []
    rightFootProgressionP = []
    rightFootPitchP = []



    for i in range(0,len(data.columns),28):
        leftPelvicP.append(patientData1[4:,i:i+3])
        leftHipP.append(patientData1[4:,i+3:i+6])
        leftKneeP.append(patientData1[4:,i+6:i+9])
        leftAnkleP.append(patientData1[4:,i+9:i+12])
        leftFootPitchP.append(patientData1[4:,i+12:i+13])
        leftFootProgressionP.append(patientData1[4:,i+13:i+14])
        
        rightPelvicP.append(patientData1[4:,i+14:i+17])
        rightHipP.append(patientData1[4:,i+17:i+20])
        rightKneeP.append(patientData1[4:,i+20:i+23])
        rightAnkleP.append(patientData1[4:,i+23:i+26])
        rightFootPitchP.append(patientData1[4:,i+26:i+27])
        rightFootProgressionP.append(patientData1[4:,i+27:i+28])


    leftPelvicP = np.array(leftPelvicP)
    leftHipP = np.array(leftHipP)
    leftKneeP = np.array(leftKneeP)
    leftAnkleP = np.array(leftAnkleP)
    leftFootPitchP = np.array(leftFootPitchP)
    leftFootProgressionP = np.array(leftFootProgressionP)

    rightPelvicP = np.array(rightPelvicP)
    rightHipP = np.array(rightHipP)
    rightKneeP = np.array(rightKneeP)
    rightAnkleP = np.array(rightAnkleP)
    rightFootPitchP = np.array(rightFootPitchP)
    rightFootProgressionP = np.array(rightFootProgressionP)
    return leftPelvicP, leftHipP, leftKneeP, leftAnkleP, leftFootPitchP, leftFootProgressionP, rightPelvicP, rightHipP, rightKneeP, rightAnkleP, rightFootPitchP, rightFootProgressionP
    
[leftPelvicP, leftHipP, leftKneeP, leftAnkleP, leftFootPitchP, leftFootProgressionP, rightPelvicP, rightHipP, rightKneeP, rightAnkleP, rightFootPitchP, rightFootProgressionP] = analysingExcelData(patientData)

# %%
##### Normality #################################

def analysingExcelData1(data):

    patientData1 = np.array(data)

    leftPelvicP = []
    leftHipP = []
    leftKneeP = []
    leftAnkleP = []
    leftFootPitchP = []
    leftFootProgressionP = []
    rightPelvicP = []
    rightHipP = []
    rightKneeP = []
    rightAnkleP = []
    rightFootProgressionP = []
    rightFootPitchP = []



    i=1
    # rightPelvicP.append(patientData1[0:,i:i+3])
    # leftPelvicP.append(patientData1[0:,i+3:i+6])
    # rightHipP.append(patientData1[0:,i+6:i+9])
    # leftHipP.append(patientData1[4:,i+9:i+12])
    # rightKneeP.append(patientData1[4:,i+12:i+15])
    # leftKneeP.append(patientData1[4:,i+15:i+18])
    # rightAnkleP.append(patientData1[4:,i+18:i+21])
    # leftAnkleP.append(patientData1[4:,i+21:i+24])


    rightPelvicP = (patientData1[0:,i:i+3])
    leftPelvicP=(patientData1[0:,i+3:i+6])
    rightHipP=(patientData1[0:,i+6:i+9])
    leftHipP=(patientData1[0:,i+9:i+12])
    rightKneeP=(patientData1[0:,i+12:i+15])
    leftKneeP=(patientData1[0:,i+15:i+18])
    rightAnkleP=(patientData1[0:,i+18:i+21])
    leftAnkleP=(patientData1[0:,i+21:i+24])


    leftPelvicP = np.array(leftPelvicP)
    leftHipP = np.array(leftHipP)
    leftKneeP = np.array(leftKneeP)
    leftAnkleP = np.array(leftAnkleP)


    rightPelvicP = np.array(rightPelvicP)
    rightHipP = np.array(rightHipP)
    rightKneeP = np.array(rightKneeP)
    rightAnkleP = np.array(rightAnkleP)

    return leftPelvicP, leftHipP, leftKneeP, leftAnkleP, rightPelvicP, rightHipP, rightKneeP, rightAnkleP

# %%
normativeDataFolderPath = "Data\\Normative dataset\\Slow Speed\\"
allFiles = glob.glob(normativeDataFolderPath+"*.xlsx")
normativeFilesNames = []
leftNormativePelvic = []
leftNormativeHip = []
leftNormativeKnee = []
leftNormativeAnkle = []
leftNormativeFootPitch = []
leftNormativeFootProgression = []

rightNormativePelvic = []
rightNormativeHip = []
rightNormativeKnee = []
rightNormativeAnkle = []
rightNormativeFootPitch = []
rightNormativeFootProgression = []
for i in range(0,41):
#for files in allFiles:
    #files = random.choice(allFiles)
    files = allFiles[i]
    #print(files)
    data = pd.read_excel(files)
    [leftPelvicP1, leftHipP1, leftKneeP1, leftAnkleP1, rightPelvicP1, rightHipP1, rightKneeP1, rightAnkleP1] = analysingExcelData1(data)
    leftNormativePelvic.append(leftPelvicP1)
    leftNormativeHip.append(leftHipP1)
    leftNormativeKnee.append(leftKneeP1)
    leftNormativeAnkle.append(leftAnkleP1)


    rightNormativePelvic.append(rightPelvicP1)
    rightNormativeHip.append(rightHipP1)
    rightNormativeKnee.append(rightKneeP1)
    rightNormativeAnkle.append(rightAnkleP1)
  
leftNormativePelvic = np.array(leftNormativePelvic)
leftNormativeHip = np.array(leftNormativeHip)
leftNormativeKnee = np.array(leftNormativeKnee)
leftNormativeAnkle = np.array(leftNormativeAnkle)


rightNormativePelvic = np.array(rightNormativePelvic)
rightNormativeHip = np.array(rightNormativeHip)
rightNormativeKnee = np.array(rightNormativeKnee)
rightNormativeAnkle = np.array(rightNormativeAnkle)

# %%
###### Plotting graphs and SPM calculated using ttest2

#### right Pelvic angles  ###########

fig = plt.figure(figsize=(12, 20))
plt.subplot(5,3,1)
spm1d.plot.plot_mean_sd(rightNormativePelvic[:,:,2])

plt.plot(np.mean(rightPelvicP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightPelvicP[:,:,0], rightNormativePelvic[:,:,2], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right pelvic tilt")
axes = plt.gca()
axes.set_ylim(0,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'purple')

plt.subplot(5,3,2)
spm1d.plot.plot_mean_sd(rightNormativePelvic[:,:,0])
plt.plot(np.mean(rightPelvicP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightPelvicP[:,:,1], rightNormativePelvic[:,:,0], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right pelvic obliquity")
axes = plt.gca()
axes.set_ylim(-15,15)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'purple')


plt.subplot(5,3,3)
spm1d.plot.plot_mean_sd(rightNormativePelvic[:,:,1])
plt.plot(np.mean(rightPelvicP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightPelvicP[:,:,2], rightNormativePelvic[:,:,1], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right pelvic rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 3, color = 'purple')

plt.subplot(5,3,4)
spm1d.plot.plot_mean_sd(rightNormativeHip[:,:,2])
plt.plot(np.mean(rightHipP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightHipP[:,:,0], rightNormativeHip[:,:,2], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right hip tilt")
axes = plt.gca()
axes.set_ylim(-20,70)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')

plt.subplot(5,3,5)
spm1d.plot.plot_mean_sd(rightNormativeHip[:,:,0])
plt.plot(np.mean(rightHipP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightHipP[:,:,1], rightNormativeHip[:,:,0], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right hip adduction")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')

plt.subplot(5,3,6)
spm1d.plot.plot_mean_sd(rightNormativeHip[:,:,1])
plt.plot(np.mean(rightHipP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightHipP[:,:,2], rightNormativeHip[:,:,1], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right hip rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')

plt.subplot(5,3,7)
spm1d.plot.plot_mean_sd(rightNormativeKnee[:,:,2])
plt.plot(np.mean(rightKneeP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightKneeP[:,:,0], rightNormativeKnee[:,:,2], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right knee flexion")
axes = plt.gca()
axes.set_ylim(-15,75)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 5, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 5, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 5, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 5, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 5, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 5, color = 'purple')

plt.subplot(5,3,8)
spm1d.plot.plot_mean_sd(rightNormativeKnee[:,:,0])
plt.plot(np.mean(rightKneeP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightKneeP[:,:,1], rightNormativeKnee[:,:,0], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right knee varus valgus")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')


plt.subplot(5,3,9)
spm1d.plot.plot_mean_sd(rightNormativeKnee[:,:,1])
plt.plot(np.mean(rightKneeP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightKneeP[:,:,2], rightNormativeKnee[:,:,1], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right knee rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')

plt.subplot(5,3,10)
spm1d.plot.plot_mean_sd(rightNormativeAnkle[:,:,2])
plt.plot(np.mean(rightAnkleP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightAnkleP[:,:,0], rightNormativeAnkle[:,:,2], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right ankle dorsiflexion")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')

plt.subplot(5,3,11)
spm1d.plot.plot_mean_sd(rightNormativeAnkle[:,:,0])
plt.plot(np.mean(rightAnkleP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightAnkleP[:,:,1], rightNormativeAnkle[:,:,0], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right ankle inversion/eversion")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')


plt.subplot(5,3,12)
spm1d.plot.plot_mean_sd(rightNormativeAnkle[:,:,1])
plt.plot(np.mean(rightAnkleP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest2(rightAnkleP[:,:,2], rightNormativeAnkle[:,:,1], equal_var=False)
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right ankle rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'darkgrey')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'dimgrey')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'plum')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'violet')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 4, color = 'purple')
    


# Define legend elements
legend_elements = [
    Line2D([0], [0], color='blue', lw=2, label='Patient Data'),
    Patch(facecolor='lightgrey', edgecolor='grey', label='Normality Band'),
    
    # Patient > Normality
    Patch(facecolor='black', label='Patient > Normal (High Statistical Significance)'),
    Patch(facecolor='dimgrey', label='Patient > Normal (Moderate Statistical Significance)'),
    Patch(facecolor='darkgrey', label='Patient > Normal (Lesser Statistical Significance)'),
    
    # Patient < Normality
    Patch(facecolor='purple', label='Patient < Normal (High Statistical Significance)'),
    Patch(facecolor='violet', label='Patient < Normal (Moderate Statistical Significance)'),
    Patch(facecolor='plum', label='Patient < Normal (Lesser Statistical Significance)')
]

# Add bold legend
fig.legend(
    handles=legend_elements,
    loc='upper right',
    frameon=True,
    title='Legend',
    title_fontproperties={'weight': 'normal'},
    prop={'weight': 'normal'}
)

# %%
#### One sample test #######

rightNormativePelvicMean = np.mean(rightNormativePelvic,axis=0)
rightNormativeHipMean = np.mean(rightNormativeHip,axis=0)
rightNormativeKneeMean = np.mean(rightNormativeKnee,axis=0)
rightNormativeAnkleMean = np.mean(rightNormativeAnkle,axis=0)

# %%
rightNormativePelvicMean[:,1].shape
# Out:
# (101,)

# %%
###### Plotting graphs and SPM calculated using ttest2

#### right Pelvic angles  ###########

plt.figure(figsize=(12, 20))
plt.subplot(5,3,1)
spm1d.plot.plot_mean_sd(rightNormativePelvic[:,:,2])
plt.plot(np.mean(rightPelvicP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightPelvicP[:,:,0], rightNormativePelvicMean[:,2])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right pelvic tilt")
axes = plt.gca()
axes.set_ylim(0,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')


plt.subplot(5,3,2)
spm1d.plot.plot_mean_sd(rightNormativePelvic[:,:,0])
plt.plot(np.mean(rightPelvicP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightPelvicP[:,:,1], rightNormativePelvicMean[:,0])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right pelvic obliquity")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')


plt.subplot(5,3,3)
spm1d.plot.plot_mean_sd(rightNormativePelvic[:,:,1])
plt.plot(np.mean(rightPelvicP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightPelvicP[:,:,2], rightNormativePelvicMean[:,1])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right pelvic rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')

plt.subplot(5,3,4)
spm1d.plot.plot_mean_sd(rightNormativeHip[:,:,2])
plt.plot(np.mean(rightHipP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightHipP[:,:,0], rightNormativeHipMean[:,2])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right hip tilt")
axes = plt.gca()
axes.set_ylim(-20,70)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')

plt.subplot(5,3,5)
spm1d.plot.plot_mean_sd(rightNormativeHip[:,:,0])
plt.plot(np.mean(rightHipP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightHipP[:,:,1], rightNormativeHipMean[:,0])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right hip adduction")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')

plt.subplot(5,3,6)
spm1d.plot.plot_mean_sd(rightNormativeHip[:,:,1])
plt.plot(np.mean(rightHipP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightHipP[:,:,2], rightNormativeHipMean[:,1])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right hip rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')

plt.subplot(5,3,7)
spm1d.plot.plot_mean_sd(rightNormativeKnee[:,:,2])
plt.plot(np.mean(rightKneeP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightKneeP[:,:,0], rightNormativeKneeMean[:,2])
ti = t.inference(alpha=0.05, two_tailed=True, interp=True)
plt.title("right knee flexion")
axes = plt.gca()
axes.set_ylim(-15,75)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')

plt.subplot(5,3,8)
spm1d.plot.plot_mean_sd(rightNormativeKnee[:,:,0])
plt.plot(np.mean(rightKneeP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightKneeP[:,:,1], rightNormativeKneeMean[:,0])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right knee varus valgus")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')


plt.subplot(5,3,9)
spm1d.plot.plot_mean_sd(rightNormativeKnee[:,:,1])
plt.plot(np.mean(rightKneeP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightKneeP[:,:,2], rightNormativeKneeMean[:,1])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right knee rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')

plt.subplot(5,3,10)
spm1d.plot.plot_mean_sd(rightNormativeAnkle[:,:,2])
plt.plot(np.mean(rightAnkleP[:,:,0],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightAnkleP[:,:,0], rightNormativeAnkleMean[:,2])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right ankle dorsiflexion")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')

plt.subplot(5,3,11)
spm1d.plot.plot_mean_sd(rightNormativeAnkle[:,:,0])
plt.plot(np.mean(rightAnkleP[:,:,1],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightAnkleP[:,:,1], rightNormativeAnkleMean[:,0])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right ankle inversion/eversion")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')


plt.subplot(5,3,12)
spm1d.plot.plot_mean_sd(rightNormativeAnkle[:,:,1])
plt.plot(np.mean(rightAnkleP[:,:,2],axis=0),linewidth = 3,color='blue')
t  = spm1d.stats.ttest(rightAnkleP[:,:,2], rightNormativeAnkleMean[:,1])
ti = t.inference(alpha=0.005, two_tailed=True, interp=True)
plt.title("right ankle rotation")
axes = plt.gca()
axes.set_ylim(-30,30)
for i in range(len(ti.clusters)):
    start = ti.clusters[i].endpoints[0]
    end = ti.clusters[i].endpoints[1]
    
    if(ti.clusters[i].threshold>0):
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'silver')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'gray')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'k')
    else:
        match ti.clusters[i].P:
            case _ if ti.clusters[i].P > 0.00025:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'moccasin')
            case _ if ti.clusters[i].P < 0.00025 and ti.clusters[i].P > 0.00005:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'wheat')
            case _ if ti.clusters[i].P < 0.00005 and ti.clusters[i].P > 0.00000:
                plt.barh(round(min(axes.get_ylim())),width = end-start,left =start, height = 2, color = 'orange')
